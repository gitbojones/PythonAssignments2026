# %% [markdown]
# <a href="https://colab.research.google.com/github/gitbojones/PythonAssignments2026/blob/main/Week1/CourseSetup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3*3)
# Out:
# 9
